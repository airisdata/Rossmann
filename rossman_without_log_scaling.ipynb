# %% [markdown]
# # Bismayan's recoding of Rossmann POC

# %% [markdown]
# ## Initial Imports

# %%
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import pandas as pd
from isoweek import Week
import random,pickle
import numpy as np
import datetime
from pandas_summary import DataFrameSummary
import feather
from functools import partial

from tensorflow.keras.layers import Input, Dense, Dropout, Flatten, Embedding,Concatenate,BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import LearningRateScheduler,ModelCheckpoint,TerminateOnNaN,TensorBoard,EarlyStopping,ReduceLROnPlateau
from keras_tqdm import TQDMNotebookCallback
from tensorflow.keras.optimizers import Adam, SGD,RMSprop

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Setting Paths

# %%
data_path="/media/2tb_hdd/deeplearning_data/rossmann_data/"
file_save_path="/media/2tb_hdd/deeplearning_data/rossmann_data/"
weights_save_path="/media/2tb_hdd/deeplearning_data/rossmann_data/saved_weights/"
submissions_path="./submissions/"
#data_path="/mnt/disks/data_disk/rossmann_data/"
#file_save_path="/mnt/disks/data_disk/rossmann_data/bismayan_files/"

# %% [markdown]
# ## Data Prep Section (Skip after first iteration)

# %% [markdown]
# ### Getting the Main Data Files

# %% [markdown]
# In addition to the provided data, we will be using external datasets put together by participants in the Kaggle competition.

# %% [markdown]
# Feature Space:
# * train: Training set provided by competition
# * store: List of stores
# * store_states: mapping of store to the German state they are in
# * List of German state names
# * googletrend: trend of certain google keywords over time, found by users to correlate well w/ given data
# * weather: weather
# * test: testing set

# %%
table_names = ['train', 'store', 'store_states', 'state_names', 
               'googletrend', 'weather', 'test']

# %%
tables = {fname:pd.read_csv(f'{data_path}{fname}.csv', low_memory=False) for fname in table_names}

# %%
for name,table in tables.items(): 
    display(f" First 5 lines for Table Name={name}")
    display(table.head())
# Out:
# ' First 5 lines for Table Name=train'
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
# ' First 5 lines for Table Name=store'
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              NaN              NaN
# 4                    2015.0       0              NaN              NaN
#
#      PromoInterval
# 0              NaN
# 1  Jan,Apr,Jul,Oct
# 2  Jan,Apr,Jul,Oct
# 3              NaN
# 4              NaN
# ' First 5 lines for Table Name=store_states'
#    Store State
# 0      1    HE
# 1      2    TH
# 2      3    NW
# 3      4    BE
# 4      5    SN
# ' First 5 lines for Table Name=state_names'
#            StateName State
# 0  BadenWuerttemberg    BW
# 1             Bayern    BY
# 2             Berlin    BE
# 3        Brandenburg    BB
# 4             Bremen    HB
# ' First 5 lines for Table Name=googletrend'
#              file                     week  trend
# 0  Rossmann_DE_SN  2012-12-02 - 2012-12-08     96
# 1  Rossmann_DE_SN  2012-12-09 - 2012-12-15     95
# 2  Rossmann_DE_SN  2012-12-16 - 2012-12-22     91
# 3  Rossmann_DE_SN  2012-12-23 - 2012-12-29     48
# 4  Rossmann_DE_SN  2012-12-30 - 2013-01-05     67
# ' First 5 lines for Table Name=weather'
#                  file        Date  Max_TemperatureC  Mean_TemperatureC  \
# 0  NordrheinWestfalen  2013-01-01                 8                  4
# 1  NordrheinWestfalen  2013-01-02                 7                  4
# 2  NordrheinWestfalen  2013-01-03                11                  8
# 3  NordrheinWestfalen  2013-01-04                 9                  9
# 4  NordrheinWestfalen  2013-01-05                 8                  8
#
#    Min_TemperatureC  Dew_PointC  MeanDew_PointC  Min_DewpointC  Max_Humidity  \
# 0                 2           7               5              1            94
# 1                 1           5               3              2            93
# 2                 6          10               8              4           100
# 3                 8           9               9              8           100
# 4                 7           8               7              6           100
#
#    Mean_Humidity       ...        Max_VisibilityKm  Mean_VisibilityKm  \
# 0             87       ...                    31.0               12.0
# 1             85       ...                    31.0               14.0
# 2             93       ...                    31.0                8.0
# 3             94       ...                    11.0                5.0
# 4             94       ...                    10.0                6.0
#
#    Min_VisibilitykM  Max_Wind_SpeedKm_h  Mean_Wind_SpeedKm_h  \
# 0               4.0                  39                   26
# 1              10.0                  24                   16
# 2               2.0                  26                   21
# 3               2.0                  23                   14
# 4               3.0                  16                   10
#
#    Max_Gust_SpeedKm_h  Precipitationmm  CloudCover  Events  WindDirDegrees
# 0                58.0             5.08         6.0    Rain             215
# 1                 NaN             0.00         6.0    Rain             225
# 2                 NaN             1.02         7.0    Rain             240
# 3                 NaN             0.25         7.0    Rain             263
# 4                 NaN             0.00         7.0    Rain             268
#
# [5 rows x 24 columns]
# ' First 5 lines for Table Name=test'
#    Id  Store  DayOfWeek        Date  Open  Promo StateHoliday  SchoolHoliday
# 0   1      1          4  2015-09-17   1.0      1            0              0
# 1   2      3          4  2015-09-17   1.0      1            0              0
# 2   3      7          4  2015-09-17   1.0      1            0              0
# 3   4      8          4  2015-09-17   1.0      1            0              0
# 4   5      9          4  2015-09-17   1.0      1            0              0

# %% [markdown]
# ### Displaying Summary of Each Dataframe

# %%
for name,table in tables.items(): 
    display(f" Dataframe Summary for Table Name={name}")
    display(DataFrameSummary(table).summary())
# Out:
# ' Dataframe Summary for Table Name=train'
#                     Store    DayOfWeek         Date        Sales    Customers  \
# count         1.01721e+06  1.01721e+06          NaN  1.01721e+06  1.01721e+06
# mean               558.43      3.99834          NaN      5773.82      633.146
# std               321.909      1.99739          NaN      3849.93      464.412
# min                     1            1          NaN            0            0
# 25%                   280            2          NaN         3727          405
# 50%                   558            4          NaN         5744          609
# 75%                   838            6          NaN         7856          837
# max                  1115            7          NaN        41551         7388
# counts            1017209      1017209      1017209      1017209      1017209
# uniques              1115            7          942        21734         4086
# missing                 0            0            0            0            0
# missing_perc           0%           0%           0%           0%           0%
# types             numeric      numeric  categorical      numeric      numeric
#
#                      Open        Promo StateHoliday SchoolHoliday
# count         1.01721e+06  1.01721e+06          NaN   1.01721e+06
# mean             0.830107     0.381515          NaN      0.178647
# std              0.375539     0.485759          NaN      0.383056
# min                     0            0          NaN             0
# 25%                     1            0          NaN             0
# 50%                     1            0          NaN             0
# 75%                     1            1          NaN             0
# max                     1            1          NaN             1
# counts            1017209      1017209      1017209       1017209
# uniques                 2            2            4             2
# missing                 0            0            0             0
# missing_perc           0%           0%           0%            0%
# types                bool         bool  categorical          bool
# ' Dataframe Summary for Table Name=store'
#                 Store    StoreType   Assortment CompetitionDistance  \
# count            1115          NaN          NaN                1112
# mean              558          NaN          NaN              5404.9
# std           322.017          NaN          NaN             7663.17
# min                 1          NaN          NaN                  20
# 25%             279.5          NaN          NaN               717.5
# 50%               558          NaN          NaN                2325
# 75%             836.5          NaN          NaN              6882.5
# max              1115          NaN          NaN               75860
# counts           1115         1115         1115                1112
# uniques          1115            4            3                 654
# missing             0            0            0                   3
# missing_perc       0%           0%           0%               0.27%
# types         numeric  categorical  categorical             numeric
#
#              CompetitionOpenSinceMonth CompetitionOpenSinceYear    Promo2  \
# count                              761                      761      1115
# mean                            7.2247                  2008.67  0.512108
# std                            3.21235                  6.19598  0.500078
# min                                  1                     1900         0
# 25%                                  4                     2006         0
# 50%                                  8                     2010         1
# 75%                                 10                     2013         1
# max                                 12                     2015         1
# counts                             761                      761      1115
# uniques                             12                       23         2
# missing                            354                      354         0
# missing_perc                    31.75%                   31.75%        0%
# types                          numeric                  numeric      bool
#
#              Promo2SinceWeek Promo2SinceYear PromoInterval
# count                    571             571           NaN
# mean                 23.5954         2011.76           NaN
# std                   14.142         1.67494           NaN
# min                        1            2009           NaN
# 25%                       13            2011           NaN
# 50%                       22            2012           NaN
# 75%                       37            2013           NaN
# max                       50            2015           NaN
# counts                   571             571           571
# uniques                   24               7             3
# missing                  544             544           544
# missing_perc          48.79%          48.79%        48.79%
# types                numeric         numeric   categorical
# ' Dataframe Summary for Table Name=store_states'
#                 Store        State
# count            1115          NaN
# mean              558          NaN
# std           322.017          NaN
# min                 1          NaN
# 25%             279.5          NaN
# 50%               558          NaN
# 75%             836.5          NaN
# max              1115          NaN
# counts           1115         1115
# uniques          1115           12
# missing             0            0
# missing_perc       0%           0%
# types         numeric  categorical
# ' Dataframe Summary for Table Name=state_names'
#              StateName   State
# count               16      16
# unique              16      16
# top             Hessen      BW
# freq                 1       1
# counts              16      16
# uniques             16      16
# missing              0       0
# missing_perc        0%      0%
# types           unique  unique
# ' Dataframe Summary for Table Name=googletrend'
#                      file         week    trend
# count                 NaN          NaN     2072
# mean                  NaN          NaN  63.8142
# std                   NaN          NaN  12.6502
# min                   NaN          NaN        0
# 25%                   NaN          NaN       55
# 50%                   NaN          NaN       64
# 75%                   NaN          NaN       72
# max                   NaN          NaN      100
# counts               2072         2072     2072
# uniques                14          148       68
# missing                 0            0        0
# missing_perc           0%           0%       0%
# types         categorical  categorical  numeric
# ' Dataframe Summary for Table Name=weather'
#                      file         Date Max_TemperatureC Mean_TemperatureC  \
# count                 NaN          NaN            15840             15840
# mean                  NaN          NaN          14.6441            10.389
# std                   NaN          NaN          8.64601           7.37926
# min                   NaN          NaN              -11               -13
# 25%                   NaN          NaN                8                 4
# 50%                   NaN          NaN               15                11
# 75%                   NaN          NaN               21                16
# max                   NaN          NaN               39                31
# counts              15840        15840            15840             15840
# uniques                16          990               51                45
# missing                 0            0                0                 0
# missing_perc           0%           0%               0%                0%
# types         categorical  categorical          numeric           numeric
#
#              Min_TemperatureC Dew_PointC MeanDew_PointC Min_DewpointC  \
# count                   15840      15840          15840         15840
# mean                  6.19899    8.58782        6.20581       3.62614
# std                   6.52639    6.24478        6.08677       6.12839
# min                       -15        -14            -15           -73
# 25%                         1          4              2            -1
# 50%                         7          9              7             4
# 75%                        11         13             11             8
# max                        24         25             20            19
# counts                  15840      15840          15840         15840
# uniques                    40         40             36            40
# missing                     0          0              0             0
# missing_perc               0%         0%             0%            0%
# types                 numeric    numeric        numeric       numeric
#
#              Max_Humidity Mean_Humidity      ...       Max_VisibilityKm  \
# count               15840         15840      ...                  15459
# mean              93.6596       74.2829      ...                24.0576
# std               7.67853       13.4866      ...                 8.9768
# min                    44            30      ...                      0
# 25%                 90.75            65      ...                     14
# 50%                    94            76      ...                     31
# 75%                   100            85      ...                     31
# max                   100           100      ...                     31
# counts              15840         15840      ...                  15459
# uniques                53            71      ...                     24
# missing                 0             0      ...                    381
# missing_perc           0%            0%      ...                  2.41%
# types             numeric       numeric      ...                numeric
#
#              Mean_VisibilityKm Min_VisibilitykM Max_Wind_SpeedKm_h  \
# count                    15459            15459              15840
# mean                   12.2398          7.02516            22.7666
# std                    5.06794           4.9806            8.98862
# min                          0                0                  3
# 25%                         10                3                 16
# 50%                         11                7                 21
# 75%                         14               10                 27
# max                         31               31                101
# counts                   15459            15459              15840
# uniques                     32               24                 44
# missing                    381              381                  0
# missing_perc             2.41%            2.41%                 0%
# types                  numeric          numeric            numeric
#
#              Mean_Wind_SpeedKm_h Max_Gust_SpeedKm_h Precipitationmm  \
# count                      15840               3604           15840
# mean                     11.9722            48.8643        0.831718
# std                      5.87284             13.027         2.51351
# min                            2                 21               0
# 25%                            8                 39               0
# 50%                           11                 48               0
# 75%                           14                 55            0.25
# max                           53                111           58.93
# counts                     15840               3604           15840
# uniques                       29                 47              41
# missing                        0              12236               0
# missing_perc                  0%             77.25%              0%
# types                    numeric            numeric         numeric
#
#              CloudCover       Events WindDirDegrees
# count             14667          NaN          15840
# mean            5.55131          NaN        175.897
# std             1.68771          NaN        101.589
# min                   0          NaN             -1
# 25%                   5          NaN             80
# 50%                   6          NaN            202
# 75%                   7          NaN            256
# max                   8          NaN            360
# counts            14667        11889          15840
# uniques               9           21            362
# missing            1173         3951              0
# missing_perc      7.41%       24.94%             0%
# types           numeric  categorical        numeric
#
# [13 rows x 24 columns]
# ' Dataframe Summary for Table Name=test'
#                    Id    Store DayOfWeek         Date      Open     Promo  \
# count           41088    41088     41088          NaN     41077     41088
# mean          20544.5    555.9   3.97917          NaN  0.854322  0.395833
# std           11861.2  320.274   2.01548          NaN  0.352787  0.489035
# min                 1        1         1          NaN         0         0
# 25%           10272.8   279.75         2          NaN         1         0
# 50%           20544.5    553.5         4          NaN         1         0
# 75%           30816.2   832.25         6          NaN         1         1
# max             41088     1115         7          NaN         1         1
# counts          41088    41088     41088        41088     41077     41088
# uniques         41088      856         7           48         2         2
# missing             0        0         0            0        11         0
# missing_perc       0%       0%        0%           0%     0.03%        0%
# types         numeric  numeric   numeric  categorical      bool      bool
#
#              StateHoliday SchoolHoliday
# count                 NaN         41088
# mean                  NaN      0.443487
# std                   NaN      0.496802
# min                   NaN             0
# 25%                   NaN             0
# 50%                   NaN             0
# 75%                   NaN             1
# max                   NaN             1
# counts              41088         41088
# uniques                 2             2
# missing                 0             0
# missing_perc           0%            0%
# types                bool          bool

# %%
print(f"Number of rows in Training set={len(tables['train'])}")
print(f"Number of rows in Test set={len(tables['test'])}")
# Out:
# Number of rows in Training set=1017209
# Number of rows in Test set=41088

# %% [markdown]
# ### Data Cleaning / Feature Engineering

# %% [markdown]
# #### Defining some generic functions

# %% [markdown]
# Function to Join two dataframes (Left outer join) with all columns in right df getting suffix _y

# %%
def join_df(left, right, left_on, right_on=None):
    if right_on is None: right_on = left_on
    return left.merge(right, how='left', left_on=left_on, right_on=right_on, 
                      suffixes=("", "_y"))

# %% [markdown]
# Function to Process Date column in dataframes and get Year/ Month/ Week/ Day

# %%
def add_datepart(df, fldname, drop=True, time=False):
    import re
    #"""add_datepart converts a column of df from a datetime64 to many columns containing
    #the information from the date. This applies changes inplace.
    #Parameters:
    #-----------
    # df: A pandas data frame. df gain several new columns.
    # fldname: A string that is the name of the date column you wish to expand.
    #     If it is not a datetime64 series, it will be converted to one with pd.to_datetime.
    # drop: If true then the original date column will be removed.
    # time: If true time features: Hour, Minute, Second will be added.
    # Examples:
    # ---------
    # >>> df = pd.DataFrame({ 'A' : pd.to_datetime(['3/11/2000', '3/12/2000', '3/13/2000'], infer_datetime_format=False) })
    #>>> df
    #    A
    # 0   2000-03-11
    # 1   2000-03-12
    # 2   2000-03-13
    # >>> add_datepart(df, 'A')
    # >>> df
    #     AYear AMonth AWeek ADay ADayofweek ADayofyear AIs_month_end AIs_month_start AIs_quarter_end AIs_quarter_start AIs_year_end AIs_year_start AElapsed
    # 0   2000  3      10    11   5          71         False         False           False           False             False        False          952732800
    # 1   2000  3      10    12   6          72         False         False           False           False             False        False          952819200
    # 2   2000  3      11    13   0          73         False         False           False           False             False        False          952905600
    # """
    fld = df[fldname]
    fld_dtype = fld.dtype
    if isinstance(fld_dtype, pd.core.dtypes.dtypes.DatetimeTZDtype):
        fld_dtype = np.datetime64

    if not np.issubdtype(fld_dtype, np.datetime64):
        df[fldname] = fld = pd.to_datetime(fld, infer_datetime_format=True)
    targ_pre = re.sub('[Dd]ate$', '', fldname)
    attr = ['Year', 'Month', 'Week', 'Day', 'Dayofweek', 'Dayofyear',
            'Is_month_end', 'Is_month_start', 'Is_quarter_end', 'Is_quarter_start', 'Is_year_end', 'Is_year_start']
    if time: attr = attr + ['Hour', 'Minute', 'Second']
    for n in attr: df[targ_pre + n] = getattr(fld.dt, n.lower())
    df[targ_pre + 'Elapsed'] = fld.astype(np.int64) // 10 ** 9
    if drop: df.drop(fldname, axis=1, inplace=True)

# %% [markdown]
# #### 1) Turning State Holidays to Boolean

# %%
tables['train'].StateHoliday = tables['train'].StateHoliday!='0'
tables['test'].StateHoliday = tables['test'].StateHoliday!='0'

# %% [markdown]
# #### 2) Joining Weather and State names

# %%
tables["weather"]= join_df(tables["weather"],tables["state_names"],left_on="file",right_on="StateName")

# %% [markdown]
# #### 3) Creating Date and State columns in Google Trends and Replacing all occurances of NI in state to HB,NI

# %%
tables['googletrend']['Date'] = tables['googletrend'].week.str.split(' - ', expand=True)[0]
tables['googletrend']['State'] = tables['googletrend'].file.str.split('_', expand=True)[2]
tables['googletrend'].loc[tables['googletrend'].State=='NI', "State"] = 'HB,NI'

# %% [markdown]
# #### 4) Adding Date Processing to all tables using datepart processing function defined above

# %%
add_datepart(tables['weather'], "Date", drop=False)
add_datepart(tables['googletrend'], "Date", drop=False)
add_datepart(tables['train'], "Date", drop=False)
add_datepart(tables['test'], "Date", drop=False)

# %% [markdown]
# #### 5) Selecting only those Google Trends that are related to Rossmann

# %%
tables['trend_de'] = tables['googletrend'][tables['googletrend'].file == 'Rossmann_DE']

# %% [markdown]
# #### 6) (Left Outer) joining all tables together

# %% [markdown]
# Join 1 : Joining store and store states

# %%
tables['store'] = join_df(tables['store'], tables['store_states'], "Store")
len(tables['store'][tables['store'].State.isnull()])
# Out:
# 0

# %% [markdown]
# Joining this store table to the train and test datasets

# %%
tables['joined'] = join_df(tables['train'], tables['store'], "Store")
tables['joined_test'] = join_df(tables['test'], tables['store'], "Store")
len(tables['joined'][tables['joined'].StoreType.isnull()])
# Out:
# 0

# %% [markdown]
# Joining these train and test tables with the googletrend dataset

# %%
tables['joined'] = join_df(tables['joined'], tables['googletrend'],["State","Year", "Week"])
tables['joined_test'] = join_df(tables['joined_test'], tables['googletrend'],["State","Year", "Week"])
len(tables['joined'][tables['joined'].trend.isnull()])
# Out:
# 0

# %% [markdown]
# Joining these train and test tables with the trend_de dataset

# %%
tables['joined'] = tables['joined'].merge(tables['trend_de'], 'left', ["Year", "Week"], suffixes=('', '_DE'))
tables['joined_test'] = tables['joined_test'].merge(tables['trend_de'], 'left', ["Year", "Week"], suffixes=('', '_DE'))
len(tables['joined'][tables['joined'].trend_DE.isnull()])
# Out:
# 0

# %% [markdown]
# Joining these train and test tables with the weather dataset

# %%
tables['joined'] = join_df(tables['joined'], tables['weather'], ["State","Date"])
tables['joined_test'] = join_df(tables['joined_test'], tables['weather'], ["State","Date"])
len(tables['joined'][tables['joined'].Mean_TemperatureC.isnull()])
# Out:
# 0

# %% [markdown]
# **Note** - Storing the results of joining in variables to save me some typing

# %%
joined= tables['joined']
joined_test= tables["joined_test"]

# %% [markdown]
# #### 7) Fill in missing values to avoid complications w/ na's.

# %%
for df in (joined,joined_test):
    df['CompetitionOpenSinceYear'] = df.CompetitionOpenSinceYear.fillna(1900).astype(np.int32)
    df['CompetitionOpenSinceMonth'] = df.CompetitionOpenSinceMonth.fillna(1).astype(np.int32)
    df['Promo2SinceYear'] = df.Promo2SinceYear.fillna(1900).astype(np.int32)
    df['Promo2SinceWeek'] = df.Promo2SinceWeek.fillna(1).astype(np.int32)

# %% [markdown]
# #### 8) Extracting Number of Days since Competitior opened

# %%
for df in (joined,joined_test):
    df["CompetitionOpenSince"] = pd.to_datetime(dict(year=df.CompetitionOpenSinceYear, 
                                                     month=df.CompetitionOpenSinceMonth, day=15))
    df["CompetitionDaysOpen"] = df.Date.subtract(df.CompetitionOpenSince).dt.days

# %% [markdown]
# Replacing outliers/ erroneous data

# %%
for df in (joined,joined_test):
    df.loc[df.CompetitionDaysOpen<0, "CompetitionDaysOpen"] = 0
    df.loc[df.CompetitionOpenSinceYear<1990, "CompetitionDaysOpen"] = 0

# %% [markdown]
# #### 9) Added "CompetitionMonthsOpen" field, limit the maximum to 2 years to limit number of unique embeddings.

# %%
for df in (joined,joined_test):    
    df["CompetitionMonthsOpen"] = df["CompetitionDaysOpen"]//30
    df.loc[df.CompetitionMonthsOpen>24, "CompetitionMonthsOpen"] = 24
    print(df.CompetitionMonthsOpen.unique())
# Out:
# [24  3 19  9  0 16 17  7 15 22 11 13  2 23 12  4 10  1 14 20  8 18  6 21
#   5]
# [24 11  0 18 19 17 21 13  9  2 14  4  6 12  3 16 10 15 20 22  5 23  7  1
#   8]

# %% [markdown]
# #### 10) Doing equivalent of steps 8 and 9 for Promo2 field

# %%
for df in (joined,joined_test):    
    df["Promo2Since"] = pd.to_datetime(df.apply(lambda x: Week(
        x.Promo2SinceYear, x.Promo2SinceWeek).monday(), axis=1).astype(pd.datetime))
    df["Promo2Days"] = df.Date.subtract(df["Promo2Since"]).dt.days
    df.loc[df.Promo2Days<0, "Promo2Days"] = 0
    df.loc[df.Promo2SinceYear<1990, "Promo2Days"] = 0
    df["Promo2Weeks"] = df["Promo2Days"]//7
    df.loc[df.Promo2Weeks<0, "Promo2Weeks"] = 0
    df.loc[df.Promo2Weeks>25, "Promo2Weeks"] = 25
    df.Promo2Weeks.unique()

# %%
for df in (joined, joined_test):
    for c in df.columns:
        if c.endswith('_y'):
            if c in df.columns: df.drop(c, inplace=True, axis=1)

# %% [markdown]
# #### 11) Dealing with Durations

# %% [markdown]
# It is common when working with time series data to extract data that explains relationships across rows as opposed to columns, e.g.:
# * Running averages
# * Time until next event
# * Time since last event
#
# This is often difficult to do with most table manipulation frameworks, since they are designed to work with relationships across columns. As such, we've created a function to handle this type of data.

# %%
columns = ["Date", "Store", "Promo", "StateHoliday", "SchoolHoliday"]

# %% [markdown]
# We've defined a fnction `get_elapsed` for cumulative counting across a sorted dataframe.
#
# Given a particular field `fld` to monitor, this object will start tracking time since the last occurrence of that field. When the field is seen again, the counter is set to zero.

# %%
def get_elapsed(fld, pre):
    day1 = np.timedelta64(1, 'D')
    last_date = np.datetime64()
    last_store = 0
    res = []

    for s,v,d in zip(df.Store.values,df[fld].values, df.Date.values):
        if s != last_store:
            last_date = np.datetime64()
            last_store = s
        if v: last_date = d
        res.append(((d-last_date).astype('timedelta64[D]') / day1))
    df[pre+fld] = res

# %%
df = tables['train'][columns].append(tables['test'][columns])

# %% [markdown]
# And a function for applying said class across dataframe rows and adding values to a new column.

# %% [markdown]
# Let's walk through an example.
#
# Say we're looking at School Holiday. We'll first sort by Store, then Date, and then call `add_elapsed('SchoolHoliday', 'After')`:
# This will generate an instance of the `elapsed` class for School Holiday:
# * Instance applied to every row of the dataframe in order of store and date
# * Will add to the dataframe the days since seeing a School Holiday
# * If we sort in the other direction, this will count the days until another promotion.

# %%
fld = 'SchoolHoliday'
df = df.sort_values(['Store', 'Date'])
get_elapsed(fld, 'After')
df = df.sort_values(['Store', 'Date'], ascending=[True, False])
get_elapsed(fld, 'Before')

# %% [markdown]
# We'll do this for two more fields.

# %%
fld = 'StateHoliday'
df = df.sort_values(['Store', 'Date'])
get_elapsed(fld, 'After')
df = df.sort_values(['Store', 'Date'], ascending=[True, False])
get_elapsed(fld, 'Before')

# %%
fld = 'Promo'
df = df.sort_values(['Store', 'Date'])
get_elapsed(fld, 'After')
df = df.sort_values(['Store', 'Date'], ascending=[True, False])
get_elapsed(fld, 'Before')

# %% [markdown]
# We're going to set the active index to Date.

# %%
df = df.set_index("Date")

# %% [markdown]
# Then set null values from elapsed field calculations to 0.

# %%
rolling_columns = ['SchoolHoliday', 'StateHoliday', 'Promo']

# %%
for o in ['Before', 'After']:
    for p in rolling_columns:
        a = o+p
        df[a] = df[a].fillna(0).astype(int)

# %% [markdown]
# Next we'll demonstrate window functions in pandas to calculate rolling quantities.
#
# Here we're sorting by date (`sort_index()`) and counting the number of events of interest (`sum()`) defined in `columns` in the following week (`rolling()`), grouped by Store (`groupby()`). We do the same in the opposite direction.

# %%
bwd = df[['Store']+rolling_columns].sort_index().groupby("Store").rolling(7, min_periods=1).sum()

# %%
fwd = df[['Store']+rolling_columns].sort_index(ascending=False
                                      ).groupby("Store").rolling(7, min_periods=1).sum()

# %%
bwd.head()
# Out:
#                   Store  SchoolHoliday  StateHoliday  Promo
# Store Date
# 1     2013-01-01    1.0            1.0           1.0    0.0
#       2013-01-02    2.0            2.0           1.0    0.0
#       2013-01-03    3.0            3.0           1.0    0.0
#       2013-01-04    4.0            4.0           1.0    0.0
#       2013-01-05    5.0            5.0           1.0    0.0

# %%
fwd.head()
# Out:
#                   Store  SchoolHoliday  StateHoliday  Promo
# Store Date
# 1     2015-09-17    1.0            0.0           0.0    1.0
#       2015-09-16    2.0            0.0           0.0    2.0
#       2015-09-15    3.0            0.0           0.0    3.0
#       2015-09-14    4.0            0.0           0.0    4.0
#       2015-09-13    5.0            0.0           0.0    4.0

# %% [markdown]
# Next we want to drop the Store indices grouped together in the window function.
#
# Often in pandas, there is an option to do this in place. This is time and memory efficient when working with large datasets.

# %%
bwd.drop('Store',1,inplace=True)
bwd.reset_index(inplace=True)
fwd.drop('Store',1,inplace=True)
fwd.reset_index(inplace=True)

# %%
df.reset_index(inplace=True)

# %%
bwd.head()
# Out:
#    Store       Date  SchoolHoliday  StateHoliday  Promo
# 0      1 2013-01-01            1.0           1.0    0.0
# 1      1 2013-01-02            2.0           1.0    0.0
# 2      1 2013-01-03            3.0           1.0    0.0
# 3      1 2013-01-04            4.0           1.0    0.0
# 4      1 2013-01-05            5.0           1.0    0.0

# %% [markdown]
# Now we'll merge these values onto the df.

# %%
df = df.merge(bwd, 'left', ['Date', 'Store'], suffixes=['', '_bw'])
df = df.merge(fwd, 'left', ['Date', 'Store'], suffixes=['', '_fw'])

# %%
df.drop(rolling_columns,1,inplace=True)

# %%
df["Date"] = pd.to_datetime(df.Date)

# %%
df.head()
# Out:
#         Date  Store  AfterSchoolHoliday  BeforeSchoolHoliday  \
# 0 2015-09-17      1                  13                    0
# 1 2015-09-16      1                  12                    0
# 2 2015-09-15      1                  11                    0
# 3 2015-09-14      1                  10                    0
# 4 2015-09-13      1                   9                    0
#
#    AfterStateHoliday  BeforeStateHoliday  AfterPromo  BeforePromo  \
# 0                105                   0           0            0
# 1                104                   0           0            0
# 2                103                   0           0            0
# 3                102                   0           0            0
# 4                101                   0           9           -1
#
#    SchoolHoliday_bw  StateHoliday_bw  Promo_bw  SchoolHoliday_fw  \
# 0               0.0              0.0       4.0               0.0
# 1               0.0              0.0       3.0               0.0
# 2               0.0              0.0       2.0               0.0
# 3               0.0              0.0       1.0               0.0
# 4               0.0              0.0       0.0               0.0
#
#    StateHoliday_fw  Promo_fw
# 0              0.0       1.0
# 1              0.0       2.0
# 2              0.0       3.0
# 3              0.0       4.0
# 4              0.0       4.0

# %% [markdown]
# Saving this File with durations handling in feather format

# %%
df.to_feather(f'{file_save_path}/df.feather')

# %%
import feather
df=feather.read_dataframe(f'{file_save_path}df.feather')

# %% [markdown]
# #### 12) Joining Durations dataframe with main data

# %%
joined = join_df(joined, df, ['Store', 'Date'])

# %%
joined_test = join_df(joined_test, df, ['Store', 'Date'])

# %%
joined.drop([x for x in joined.columns if x[-2:]=='_y'],axis=1,inplace=True)
joined_test.drop([x for x in joined_test.columns if x[-2:]=='_y'],axis=1,inplace=True)

# %%
joined.to_feather(f'{file_save_path}/joined.feather')
joined_test.to_feather(f'{file_save_path}/joined_test.feather')

# %% [markdown]
# ## Preprocessing for Modelling (Restart from here to skip feature engineering)

# %%
joined=feather.read_dataframe(f'{file_save_path}/joined.feather')

# %%
from sklearn_pandas import DataFrameMapper
from sklearn.preprocessing import LabelEncoder, Imputer, StandardScaler

# %% [markdown]
# This dictionary maps categories to embedding dimensionality. In generally, categories we might expect to be conceptually more complex have larger dimension.

# %%
#cat_var_dict = {'Store': 50, 'DayOfWeek': 6, 'Year': 2, 'Month': 6,
#'Day': 10, 'StateHoliday': 3, 'CompetitionMonthsOpen': 2,
#'Promo2Weeks': 1, 'StoreType': 2, 'Assortment': 3, 'PromoInterval': 3,
#'CompetitionOpenSinceYear': 4, 'Promo2SinceYear': 4, 'State': 6,
#'Week': 2, 'Events': 4, 'Promo_fw': 1,
#'Promo_bw': 1, 'StateHoliday_fw': 1,
#'StateHoliday_bw': 1, 'SchoolHoliday_fw': 1,
#'SchoolHoliday_bw': 1}

cat_var_dict = {'Store': 50, 'DayOfWeek': 4, 'Year': 2, 'Month': 7,
'Day': 16, 'StateHoliday': 2, 'CompetitionMonthsOpen': 13,
'Promo2Weeks': 14, 'StoreType': 3, 'Assortment': 2, 'PromoInterval': 2,
'CompetitionOpenSinceYear': 12, 'Promo2SinceYear': 5, 'State': 7,
'Week': 27, 'Events': 11, 'Promo_fw': 4,
'Promo_bw': 4, 'StateHoliday_fw': 2,
'StateHoliday_bw': 2, 'SchoolHoliday_fw': 5,
'SchoolHoliday_bw': 5}

# %% [markdown]
# Name categorical variables (sorted in order of embedding size)

# %%
cat_vars = [o[0] for o in 
            sorted(cat_var_dict.items(),key=lambda x:x[1], reverse=True)]

# %% [markdown]
# Name continuous Variables

# %%
contin_vars = ['CompetitionDistance', 
   'Max_TemperatureC', 'Mean_TemperatureC', 'Min_TemperatureC',
   'Max_Humidity', 'Mean_Humidity', 'Min_Humidity', 'Max_Wind_SpeedKm_h', 
   'Mean_Wind_SpeedKm_h', 'CloudCover', 'trend', 'trend_DE',
   'AfterStateHoliday', 'BeforeStateHoliday', 'Promo', 'SchoolHoliday']

# %% [markdown]
# Replace nulls w/ 0 for continuous, "" for categorical.

# %%
for v in contin_vars: joined.loc[joined[v].isnull(), v] = 0
for v in cat_vars: joined.loc[joined[v].isnull(), v] = ""

# %%
cat_maps = [(o, LabelEncoder()) for o in cat_vars]
contin_maps = [([o], StandardScaler()) for o in contin_vars]

# %% [markdown]
# The same instances need to be used for the test set as well, so values are mapped/standardized appropriately.
#
# DataFrame mapper will keep track of these variable-instance mappings.

# %%
cat_mapper = DataFrameMapper(cat_maps)
cat_map_fit = cat_mapper.fit(joined)
cat_cols = len(cat_map_fit.features)
cat_cols
# Out:
# 22

# %%
contin_mapper = DataFrameMapper(contin_maps)
contin_map_fit = contin_mapper.fit(joined)
contin_cols = len(contin_map_fit.features)
contin_cols
# Out:
# 16

# %% [markdown]
# We can also pickle these mappings, which is great for portability!

# %%
pickle.dump(contin_map_fit, open(f'{file_save_path}contin_maps.pickle', 'wb'))
pickle.dump(cat_map_fit, open(f'{file_save_path}cat_maps.pickle', 'wb'))

# %% [markdown]
# ### Taking Sample (Set sample size to length of df to train on full dataset)

# %%
joined_sales = joined[joined.Sales!=0]
n = len(joined_sales)

# %%
samp_size = n
np.random.seed(1234)
idxs = sorted(np.random.choice(n, samp_size, replace=False),reverse=True)
joined_samp = joined_sales.iloc[idxs].set_index("Date")

# %% [markdown]
# In time series data, cross-validation is not random. Instead, our holdout data is always the most recent data, as it would be in real application.

# %%
train_ratio = 0.9
train_size = int(samp_size * train_ratio)
print(train_size)
joined_valid = joined_samp[train_size:]
joined_train = joined_samp[:train_size]
len(joined_valid), len(joined_train)
# Out:
# 759904
# (84434, 759904)

# %% [markdown]
# Here are preprocessors for our categoricals and continuous variables using our instance mapper.

# %%
def cat_preproc(dat):
    return cat_map_fit.transform(dat).astype(np.int64)
def contin_preproc(dat):
    return contin_map_fit.transform(dat).astype(np.float32)

# %%
cat_map_train = cat_preproc(joined_train)
cat_map_valid = cat_preproc(joined_valid)
contin_map_train = contin_preproc(joined_train)
contin_map_valid = contin_preproc(joined_valid)

# %% [markdown]
# Grab our targets.

# %%
y_train = joined_train.Sales
y_valid = joined_valid.Sales

# %% [markdown]
# ### Creating Model Inputs

# %%
def split_cols(arr): return np.hsplit(arr,arr.shape[1])

# %%
map_train = split_cols(cat_map_train) + [contin_map_train]
map_valid = split_cols(cat_map_valid) + [contin_map_valid]

# %%
len(map_train),len(map_valid)
# Out:
# (23, 23)

# %% [markdown]
# Helper function for getting categorical name and dim.

# %%
def cat_map_info(feat): return feat[0], len(feat[1].classes_)

# %% [markdown]
# Note we're flattening the embedding. Embeddings in Keras come out as an element of a sequence like we might use in a sequence of words; here we just want to concatenate them so we flatten the 1-vector sequence into a vector.

# %%
def get_emb(feat):
    name, c = cat_map_info(feat)
    c2 = (c+1)//2
    if c2>50: c2=50
    inp = Input((1,), dtype='int64', name=name+'_in')
    emb=Embedding(c, c2, input_length=1, embeddings_initializer="RandomNormal",name=name+"_embed")(inp)
    u = Flatten(name=name+'_flt')(emb)
    return inp,u

# %% [markdown]
# ### Defining RMSPE Keras Loss

# %%
def rmspe_loss(y_true,y_pred):
    import tensorflow.keras.backend as K
    diff = K.square((y_true - y_pred) / K.clip(K.abs(y_true),
                                            K.epsilon(),
                                            None))
    return  K.sqrt(K.mean(diff, axis=-1))

# %% [markdown]
# ## Some Misc Utility Functions

# %% [markdown]
# ### Defining some custom learning rate schedulers

# %%
def schedule_lr(epoch,interval=5, multiplier=0.3,base_rate=0.01):
    exp=int((epoch)%interval)
    return base_rate*(multiplier**exp)

def cosine_lr(epoch,base_rate,interval=10):
    import numpy as np
    lr= base_rate*np.cos(int(epoch%interval)*np.pi/(4*interval))
    return lr

# %% [markdown]
# ### Function to plot Training histories

# %%
def plot_history(hist):
    plt.figure(figsize=(20,8))
    plt.suptitle("Training Curve",fontsize=20)
    plt.plot(hist.history["loss"],'ro-',label="Training loss")
    plt.plot(hist.history["val_loss"],'bo-',label="Validation loss")
    plt.grid()
    plt.xlabel("Epoch",fontsize=18)
    plt.ylabel("Loss",fontsize=18)
    plt.legend(fontsize=18)

# %% [markdown]
# ### Function to generate Test Predictions

# %%
def generate_preds_df(model,joined_load_loc=f'{file_save_path}/joined_test.feather',model_weights_path=None):
    joined_test=feather.read_dataframe(f'{file_save_path}/joined_test.feather')
    
    for v in contin_vars: joined_test.loc[joined_test[v].isnull(), v] = 0
    for v in cat_vars: joined_test.loc[joined_test[v].isnull(), v] = ""
    cat_map_test = cat_preproc(joined_test)
    contin_map_test = contin_preproc(joined_test)
    map_test = split_cols(cat_map_test) + [contin_map_test]
    
    if model_weights_path is not None:
        model.load_weights(f"{model_weights_path}")
    
    test_preds=model.predict(map_test)
    preds_submit= pd.DataFrame(joined_test["Id"])
    preds_submit["Sales"]=test_preds
    return preds_submit

# %% [markdown]
# ### Function to generate train and validation results

# %%
def get_train_and_valid_results(model,model_weights_path=None,\
                                return_cols=["Store","State","DayOfWeek","Sales","Customers","Open","Promo","StateHoliday","SchoolHoliday"]\
                               ):
    if model_weights_path is not None:
        model.load_weights(f'{model_weights_path}')
    pred_train=model.predict(map_train)
    pred_valid=model.predict(map_valid)
    save_train= joined_train[return_cols]
    save_valid= joined_valid[return_cols]
    save_train["PredictedSales"]=pred_train
    save_valid["PredictedSales"]=pred_valid
    return save_train,save_valid

# %% [markdown]
# ### Function to generate train and validation plots

# %%
def plot_results(filter_field,filter_value,train_df=save_train,valid_df=save_valid):
    train_df[train_df[filter_field]==filter_value].plot(y=["Sales","PredictedSales"],figsize=(25,10),grid=True)
    valid_df[valid_df[filter_field]==filter_value].plot(y=["Sales","PredictedSales"],figsize=(25,10),grid=True)
    return

# %% [markdown]
# ### Displaying embeddings in Tensorboard

# %%
def create_tboard_logs(model,model_weights_path=None,tboard_logdir="./tboard_logs"):
    import tensorflow as tf
    import tensorflow.keras as keras
    if model_weights_path is not None:
        model.load_weights(model_weights_path)
    saver = tf.train.Saver()
    sess = keras.backend.get_session()
    save_path = saver.save(sess, f"{tboard_logdir}/model.ckpt")
    
    total_string=""
    for i in cat_maps:
        np.savetxt(f"tboard_logs/{i[0]}_metadata.tsv",i[1].classes_,fmt='%s', delimiter="\n")
        write_string=f'''
                     embeddings {{
                                 tensor_name: "{i[0]}_embed/embeddings"
                                 metadata_path:"{i[0]}_metadata.tsv" 
                    }}
                    '''
        total_string= total_string+write_string
        
    with open(f"{tboard_logdir}/projector_config.pbtxt","w") as f:
        print(total_string,file=f)   
    return

# %% [markdown]
# ### Model Fitting Wrapper Function

# %%
def model_fitter(model,train_x,train_y,validation_data,\
                 checkpoint_path,previous_weights_path=None,checkpoint_verbosity=0,\
                 max_epochs=100,batch_size=512):

    checkpoint= ModelCheckpoint(checkpoint_path,monitor="val_loss",save_best_only=True,verbose=checkpoint_verbosity)
    term= TerminateOnNaN()
    tqdm_callback= TQDMNotebookCallback(leave_inner=True,metric_format='{name}: {value:0.5f}')
    early_stop= EarlyStopping(monitor="val_loss",patience=8,min_delta=0,mode="min",verbose=1)
    reduce_lr=ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=4, verbose=1, mode='auto', min_delta=0.0005, cooldown=0, min_lr=1e-6)

    try:
        model.load_weights(previous_weights_path)
        print("Loading model Weights from previous model")
    except:
        print("Not loading model Weights from previous model")
    hist = model.fit(train_x,train_y, batch_size=batch_size, epochs=max_epochs,
                     verbose=0, validation_data=validation_data,callbacks=[checkpoint,reduce_lr,term,tqdm_callback,early_stop])

    plot_history(hist)

    print("Reloading Best Checkpointed weights")
    model.load_weights(checkpoint_path)
    print("Model Training Loss (Without Dropout)=",model.evaluate(map_train,y_train,verbose=0))
    print("Model Validation Loss=",model.evaluate(map_valid,y_valid,verbose=0))
    return hist,model

# %% [markdown]
# ## Bigger Model

# %% [markdown]
# ### Building Model

# %%
contin_inp = Input((contin_cols,), name='contin')
contin_out = Dense(contin_cols*10, activation='relu', name='contin_d')(contin_inp)
embs = [get_emb(feat) for feat in cat_map_fit.features]
x = Concatenate(axis=-1)([emb for inp,emb in embs] + [contin_out])
x=BatchNormalization()(x)
x = Dropout(0.05)(x)
x = Dense(1024, activation='relu')(x)
x = Dense(512, activation='relu')(x)
x=BatchNormalization()(x)
x = Dropout(0.1)(x)
x = Dense(256, activation='relu')(x)
x = Dense(128, activation='relu')(x)
x=BatchNormalization()(x)
x = Dropout(0.1)(x)
x = Dense(1, activation=None)(x)

model = Model([inp for inp,emb in embs] + [contin_inp], x)
model.compile(RMSprop(lr=0.01,clipvalue=5.0), loss=rmspe_loss)

# %% [markdown]
# ### Training Model

# %%
hist,model=model_fitter(model,map_train,y_train,validation_data=(map_valid,y_valid),checkpoint_path=f"{weights_save_path}saved_model_big")
# Out:
# Not loading model Weights from previous model
# HBox(children=(IntProgress(value=0, description='Training', style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='Epoch 0', max=759904, style=ProgressStyle(description_width='…
# HBox(children=(IntProgress(value=0, description='Epoch 1', max=759904, style=ProgressStyle(description_width='…
# HBox(children=(IntProgress(value=0, description='Epoch 2', max=759904, style=ProgressStyle(description_width='…
# HBox(children=(IntProgress(value=0, description='Epoch 3', max=759904, style=ProgressStyle(description_width='…
# HBox(children=(IntProgress(value=0, description='Epoch 4', max=759904, style=ProgressStyle(description_width='…
# HBox(children=(IntProgress(value=0, description='Epoch 5', max=759904, style=ProgressStyle(description_width='…
# HBox(children=(IntProgress(value=0, description='Epoch 6', max=759904, style=ProgressStyle(description_width='…
# HBox(children=(IntProgress(value=0, description='Epoch 7', max=759904, style=ProgressStyle(description_width='…
# HBox(children=(IntProgress(value=0, description='Epoch 8', max=759904, style=ProgressStyle(description_width='…
# HBox(children=(IntProgress(value=0, description='Epoch 9', max=759904, style=ProgressStyle(description_width='…
# HBox(children=(IntProgress(value=0, description='Epoch 10', max=759904, style=ProgressStyle(description_width=…
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0019999999552965165.
# HBox(children=(IntProgress(value=0, description='Epoch 11', max=759904, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Epoch 12', max=759904, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Epoch 13', max=759904, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Epoch 14', max=759904, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Epoch 15', max=759904, style=ProgressStyle(description_width=…
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0003999999724328518.
# HBox(children=(IntProgress(value=0, description='Epoch 16', max=759904, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Epoch 17', max=759904, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Epoch 18', max=759904, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Epoch 19', max=759904, style=ProgressStyle(description_width=…
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 7.999999215826393e-05.
# HBox(children=(IntProgress(value=0, description='Epoch 20', max=759904, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Epoch 21', max=759904, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Epoch 22', max=759904, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Epoch 23', max=759904, style=ProgressStyle(description_width=…
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 1.599999814061448e-05.
# HBox(children=(IntProgress(value=0, description='Epoch 24', max=759904, style=ProgressStyle(description_width=…
# Epoch 00025: early stopping
# Reloading Best Checkpointed weights
# Model Training Loss (Without Dropout)= 0.05375224303338231
# Model Validation Loss= 0.0840087374540152

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Store_in (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# Week_in (InputLayer)            (None, 1)            0
# __________________________________________________________________________________________________
# Day_in (InputLayer)             (None, 1)            0
# __________________________________________________________________________________________________
# Promo2Weeks_in (InputLayer)     (None, 1)            0
# __________________________________________________________________________________________________
# CompetitionMonthsOpen_in (Input (None, 1)            0
# __________________________________________________________________________________________________
# CompetitionOpenSinceYear_in (In (None, 1)            0
# __________________________________________________________________________________________________
# Events_in (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# Month_in (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# State_in (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# Promo2SinceYear_in (InputLayer) (None, 1)            0
# __________________________________________________________________________________________________
# SchoolHoliday_fw_in (InputLayer (None, 1)            0
# __________________________________________________________________________________________________
# SchoolHoliday_bw_in (InputLayer (None, 1)            0
# __________________________________________________________________________________________________
# DayOfWeek_in (InputLayer)       (None, 1)            0
# __________________________________________________________________________________________________
# Promo_fw_in (InputLayer)        (None, 1)            0
# __________________________________________________________________________________________________
# Promo_bw_in (InputLayer)        (None, 1)            0
# __________________________________________________________________________________________________
# StoreType_in (InputLayer)       (None, 1)            0
# __________________________________________________________________________________________________
# Year_in (InputLayer)            (None, 1)            0
# __________________________________________________________________________________________________
# StateHoliday_in (InputLayer)    (None, 1)            0
# __________________________________________________________________________________________________
# Assortment_in (InputLayer)      (None, 1)            0
# __________________________________________________________________________________________________
# PromoInterval_in (InputLayer)   (None, 1)            0
# __________________________________________________________________________________________________
# StateHoliday_fw_in (InputLayer) (None, 1)            0
# __________________________________________________________________________________________________
# StateHoliday_bw_in (InputLayer) (None, 1)            0
# __________________________________________________________________________________________________
# Store_embed (Embedding)         (None, 1, 50)        55750       Store_in[0][0]
# __________________________________________________________________________________________________
# Week_embed (Embedding)          (None, 1, 26)        1352        Week_in[0][0]
# __________________________________________________________________________________________________
# Day_embed (Embedding)           (None, 1, 16)        496         Day_in[0][0]
# __________________________________________________________________________________________________
# Promo2Weeks_embed (Embedding)   (None, 1, 13)        338         Promo2Weeks_in[0][0]
# __________________________________________________________________________________________________
# CompetitionMonthsOpen_embed (Em (None, 1, 13)        325         CompetitionMonthsOpen_in[0][0]
# __________________________________________________________________________________________________
# CompetitionOpenSinceYear_embed  (None, 1, 12)        276         CompetitionOpenSinceYear_in[0][0]
# __________________________________________________________________________________________________
# Events_embed (Embedding)        (None, 1, 11)        242         Events_in[0][0]
# __________________________________________________________________________________________________
# Month_embed (Embedding)         (None, 1, 6)         72          Month_in[0][0]
# __________________________________________________________________________________________________
# State_embed (Embedding)         (None, 1, 6)         72          State_in[0][0]
# __________________________________________________________________________________________________
# Promo2SinceYear_embed (Embeddin (None, 1, 4)         32          Promo2SinceYear_in[0][0]
# __________________________________________________________________________________________________
# SchoolHoliday_fw_embed (Embeddi (None, 1, 4)         32          SchoolHoliday_fw_in[0][0]
# __________________________________________________________________________________________________
# SchoolHoliday_bw_embed (Embeddi (None, 1, 4)         32          SchoolHoliday_bw_in[0][0]
# __________________________________________________________________________________________________
# DayOfWeek_embed (Embedding)     (None, 1, 4)         28          DayOfWeek_in[0][0]
# __________________________________________________________________________________________________
# Promo_fw_embed (Embedding)      (None, 1, 3)         18          Promo_fw_in[0][0]
# __________________________________________________________________________________________________
# Promo_bw_embed (Embedding)      (None, 1, 3)         18          Promo_bw_in[0][0]
# __________________________________________________________________________________________________
# StoreType_embed (Embedding)     (None, 1, 2)         8           StoreType_in[0][0]
# __________________________________________________________________________________________________
# Year_embed (Embedding)          (None, 1, 2)         6           Year_in[0][0]
# __________________________________________________________________________________________________
# StateHoliday_embed (Embedding)  (None, 1, 1)         2           StateHoliday_in[0][0]
# __________________________________________________________________________________________________
# Assortment_embed (Embedding)    (None, 1, 2)         6           Assortment_in[0][0]
# __________________________________________________________________________________________________
# PromoInterval_embed (Embedding) (None, 1, 2)         8           PromoInterval_in[0][0]
# __________________________________________________________________________________________________
# StateHoliday_fw_embed (Embeddin (None, 1, 2)         6           StateHoliday_fw_in[0][0]
# __________________________________________________________________________________________________
# StateHoliday_bw_embed (Embeddin (None, 1, 2)         6           StateHoliday_bw_in[0][0]
# __________________________________________________________________________________________________
# contin (InputLayer)             (None, 16)           0
# __________________________________________________________________________________________________
# Store_flt (Flatten)             (None, 50)           0           Store_embed[0][0]
# __________________________________________________________________________________________________
# Week_flt (Flatten)              (None, 26)           0           Week_embed[0][0]
# __________________________________________________________________________________________________
# Day_flt (Flatten)               (None, 16)           0           Day_embed[0][0]
# __________________________________________________________________________________________________
# Promo2Weeks_flt (Flatten)       (None, 13)           0           Promo2Weeks_embed[0][0]
# __________________________________________________________________________________________________
# CompetitionMonthsOpen_flt (Flat (None, 13)           0           CompetitionMonthsOpen_embed[0][0]
# __________________________________________________________________________________________________
# CompetitionOpenSinceYear_flt (F (None, 12)           0           CompetitionOpenSinceYear_embed[0]
# __________________________________________________________________________________________________
# Events_flt (Flatten)            (None, 11)           0           Events_embed[0][0]
# __________________________________________________________________________________________________
# Month_flt (Flatten)             (None, 6)            0           Month_embed[0][0]
# __________________________________________________________________________________________________
# State_flt (Flatten)             (None, 6)            0           State_embed[0][0]
# __________________________________________________________________________________________________
# Promo2SinceYear_flt (Flatten)   (None, 4)            0           Promo2SinceYear_embed[0][0]
# __________________________________________________________________________________________________
# SchoolHoliday_fw_flt (Flatten)  (None, 4)            0           SchoolHoliday_fw_embed[0][0]
# __________________________________________________________________________________________________
# SchoolHoliday_bw_flt (Flatten)  (None, 4)            0           SchoolHoliday_bw_embed[0][0]
# __________________________________________________________________________________________________
# DayOfWeek_flt (Flatten)         (None, 4)            0           DayOfWeek_embed[0][0]
# __________________________________________________________________________________________________
# Promo_fw_flt (Flatten)          (None, 3)            0           Promo_fw_embed[0][0]
# __________________________________________________________________________________________________
# Promo_bw_flt (Flatten)          (None, 3)            0           Promo_bw_embed[0][0]
# __________________________________________________________________________________________________
# StoreType_flt (Flatten)         (None, 2)            0           StoreType_embed[0][0]
# __________________________________________________________________________________________________
# Year_flt (Flatten)              (None, 2)            0           Year_embed[0][0]
# __________________________________________________________________________________________________
# StateHoliday_flt (Flatten)      (None, 1)            0           StateHoliday_embed[0][0]
# __________________________________________________________________________________________________
# Assortment_flt (Flatten)        (None, 2)            0           Assortment_embed[0][0]
# __________________________________________________________________________________________________
# PromoInterval_flt (Flatten)     (None, 2)            0           PromoInterval_embed[0][0]
# __________________________________________________________________________________________________
# StateHoliday_fw_flt (Flatten)   (None, 2)            0           StateHoliday_fw_embed[0][0]
# __________________________________________________________________________________________________
# StateHoliday_bw_flt (Flatten)   (None, 2)            0           StateHoliday_bw_embed[0][0]
# __________________________________________________________________________________________________
# contin_d (Dense)                (None, 160)          2720        contin[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 348)          0           Store_flt[0][0]
#                                                                  Week_flt[0][0]
#                                                                  Day_flt[0][0]
#                                                                  Promo2Weeks_flt[0][0]
#                                                                  CompetitionMonthsOpen_flt[0][0]
#                                                                  CompetitionOpenSinceYear_flt[0][0
#                                                                  Events_flt[0][0]
#                                                                  Month_flt[0][0]
#                                                                  State_flt[0][0]
#                                                                  Promo2SinceYear_flt[0][0]
#                                                                  SchoolHoliday_fw_flt[0][0]
#                                                                  SchoolHoliday_bw_flt[0][0]
#                                                                  DayOfWeek_flt[0][0]
#                                                                  Promo_fw_flt[0][0]
#                                                                  Promo_bw_flt[0][0]
#                                                                  StoreType_flt[0][0]
#                                                                  Year_flt[0][0]
#                                                                  StateHoliday_flt[0][0]
#                                                                  Assortment_flt[0][0]
#                                                                  PromoInterval_flt[0][0]
#                                                                  StateHoliday_fw_flt[0][0]
#                                                                  StateHoliday_bw_flt[0][0]
#                                                                  contin_d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 348)          1392        concatenate_1[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 348)          0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1024)         357376      dropout_3[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 512)          524800      dense_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 512)          2048        dense_6[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 512)          0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 256)          131328      dropout_4[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 128)          32896       dense_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 128)          512         dense_8[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 128)          0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 1)            129         dropout_5[0][0]
# ==================================================================================================
# Total params: 1,112,326
# Trainable params: 1,110,350
# Non-trainable params: 1,976
# __________________________________________________________________________________________________

# %% [markdown]
# ### Generating Predictions

# %%
preds_submit= generate_preds_df(model,model_weights_path=f"{weights_save_path}saved_backup_big_0.08401")
preds_submit.head()
# Out:
#    Id        Sales
# 0   1  4376.350098
# 1   2  7337.701172
# 2   3  9533.083984
# 3   4  7176.228027
# 4   5  7348.005371

# %%
preds_submit.to_csv(f"{submissions_path}submit_new.csv",index=False)

# %% [markdown]
# ### Plotting Predictions on Train and Validation data

# %%
save_train,save_valid= get_train_and_valid_results(model,model_weights_path=f"{weights_save_path}saved_backup_big_0.08401")

# %%
plot_results("Store",45)

# %% [markdown]
# ### Displaying embeddings in Tensorboard

# %%
create_tboard_logs(model,model_weights_path=f"{weights_save_path}saved_backup_big_0.08401")

# %% [markdown]
# ### Retraining on whole data

# %%
## Reminder best results till now for 8487
model.compile(RMSprop(lr=0.001,clipvalue=1.0), loss=rmspe_loss)
model.load_weights(f"{weights_save_path}saved_backup_big_0.08401")

# %%
map_total=[np.vstack((map_train[i],map_valid[i])) for i in range(len(map_train))]
y_total=y_train.append(y_valid)

# %%
model.fit(map_total,y_total,epochs=10,batch_size=512)
# Out:
# Epoch 1/10
# 844338/844338 [==============================] - 31s 36us/step - loss: 0.0670
# Epoch 2/10
# 844338/844338 [==============================] - 15s 18us/step - loss: 0.0665
# Epoch 3/10
# 844338/844338 [==============================] - 14s 16us/step - loss: 0.0661
# Epoch 4/10
# 844338/844338 [==============================] - 14s 17us/step - loss: 0.0658
# Epoch 5/10
# 844338/844338 [==============================] - 15s 17us/step - loss: 0.0656
# Epoch 6/10
# 844338/844338 [==============================] - 15s 18us/step - loss: 0.0655
# Epoch 7/10
# 844338/844338 [==============================] - 15s 18us/step - loss: 0.0655
# Epoch 8/10
# 844338/844338 [==============================] - 14s 16us/step - loss: 0.0651
# Epoch 9/10
# 844338/844338 [==============================] - 14s 17us/step - loss: 0.0651
# Epoch 10/10
# 844338/844338 [==============================] - 15s 18us/step - loss: 0.0649

# %%
preds_full= generate_preds_df(model)
preds_full.head()
# Out:
#    Id        Sales
# 0   1  4299.072754
# 1   2  7442.999023
# 2   3  9667.871094
# 3   4  7145.963867
# 4   5  7283.107910

# %%
preds_full.to_csv(f"{submissions_path}submit_full31.csv",index=False)

# %%
import tensorflow.keras.backend as K

# %%
K.set_value(model.optimizer.lr,0.0001)
model.fit(map_total,y_total,epochs=10,batch_size=512)
# Out:
# Epoch 1/10
# 844338/844338 [==============================] - 15s 17us/step - loss: 0.0646
# Epoch 2/10
# 844338/844338 [==============================] - 15s 18us/step - loss: 0.0643
# Epoch 3/10
# 844338/844338 [==============================] - 16s 18us/step - loss: 0.0644
# Epoch 4/10
# 844338/844338 [==============================] - 14s 17us/step - loss: 0.0643
# Epoch 5/10
# 844338/844338 [==============================] - 14s 17us/step - loss: 0.0643
# Epoch 6/10
# 844338/844338 [==============================] - 15s 18us/step - loss: 0.0644
# Epoch 7/10
# 844338/844338 [==============================] - 15s 17us/step - loss: 0.0642
# Epoch 8/10
# 844338/844338 [==============================] - 15s 18us/step - loss: 0.0643
# Epoch 9/10
# 844338/844338 [==============================] - 16s 19us/step - loss: 0.0643
# Epoch 10/10
# 844338/844338 [==============================] - 14s 17us/step - loss: 0.0642

# %%
K.set_value(model.optimizer.lr,0.00005)
model.fit(map_total,y_total,epochs=10,batch_size=512)
# Out:
# Epoch 1/10
# 844338/844338 [==============================] - 14s 16us/step - loss: 0.0642
# Epoch 2/10
# 844338/844338 [==============================] - 15s 18us/step - loss: 0.0641
# Epoch 3/10
# 844338/844338 [==============================] - 14s 17us/step - loss: 0.0642
# Epoch 4/10
# 844338/844338 [==============================] - 15s 18us/step - loss: 0.0642
# Epoch 5/10
# 844338/844338 [==============================] - 16s 19us/step - loss: 0.0642
# Epoch 6/10
# 844338/844338 [==============================] - 14s 17us/step - loss: 0.0642
# Epoch 7/10
# 844338/844338 [==============================] - 15s 18us/step - loss: 0.0641
# Epoch 8/10
# 844338/844338 [==============================] - 15s 18us/step - loss: 0.0642
# Epoch 9/10
# 844338/844338 [==============================] - 13s 16us/step - loss: 0.0642
# Epoch 10/10
# 844338/844338 [==============================] - 15s 18us/step - loss: 0.0642

# %%
preds_full= generate_preds_df(model)
preds_full.head()
# Out:
#    Id        Sales
# 0   1  4313.044434
# 1   2  7492.222168
# 2   3  9622.715820
# 3   4  7194.741211
# 4   5  7387.603516

# %%
preds_full.to_csv(f"{submissions_path}submit_full32.csv",index=False)

# %%
model.save_weights(f"{weights_save_path}full_retrain_best_weights")
# Out:
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.RMSprop object at 0x7f80a6ed3a20>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.

# %%
K.set_value(model.optimizer.lr,0.000001)
model.fit(map_total,y_total,epochs=10,batch_size=512)
# Out:
# Epoch 1/10
# 844338/844338 [==============================] - 15s 17us/step - loss: 0.0673
# Epoch 2/10
# 844338/844338 [==============================] - 17s 20us/step - loss: 0.0673
# Epoch 3/10
# 844338/844338 [==============================] - 16s 19us/step - loss: 0.0673
# Epoch 4/10
# 844338/844338 [==============================] - 15s 18us/step - loss: 0.0673
# Epoch 5/10
# 844338/844338 [==============================] - 14s 17us/step - loss: 0.0674
# Epoch 6/10
# 844338/844338 [==============================] - 16s 19us/step - loss: 0.0672
# Epoch 7/10
# 844338/844338 [==============================] - 15s 17us/step - loss: 0.0671
# Epoch 8/10
# 844338/844338 [==============================] - 15s 17us/step - loss: 0.0671
# Epoch 9/10
# 844338/844338 [==============================] - 15s 17us/step - loss: 0.0672
# Epoch 10/10
# 844338/844338 [==============================] - 15s 18us/step - loss: 0.0673

# %%
preds_full= generate_preds_df(model)
preds_full.head()
# Out:
#    Id        Sales
# 0   1  4377.520508
# 1   2  7062.202637
# 2   3  9496.666016
# 3   4  7704.852539
# 4   5  7462.537598

# %%
preds_full.to_csv(f"{submissions_path}submit_full31.csv",index=False)

# %% [markdown]
# #### Testing out limited retraining

# %%
model.compile(RMSprop(lr=0.001,clipvalue=1.0), loss=rmspe_loss)
model.load_weights(f"{weights_save_path}saved_backup_big_0.08401")

# %%
model.fit(map_total,y_total,epochs=3,batch_size=512)
# Out:
# Epoch 1/3
# 844338/844338 [==============================] - 31s 37us/step - loss: 0.0670
# Epoch 2/3
# 844338/844338 [==============================] - 14s 17us/step - loss: 0.0664
# Epoch 3/3
# 844338/844338 [==============================] - 16s 19us/step - loss: 0.0660

# %%
preds_full= generate_preds_df(model)
preds_full.head()
# Out:
#    Id        Sales
# 0   1  4352.633789
# 1   2  7420.615234
# 2   3  9637.626953
# 3   4  7160.165039
# 4   5  7377.948242

# %%
preds_full.to_csv(f"{submissions_path}submit_full35.csv",index=False)

# %% [markdown]
# ## Simpler Model

# %% [markdown]
# ### Building Model

# %%
from tensorflow.keras.layers import Input, Dense, Dropout, Flatten, Embedding,Concatenate,BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import LearningRateScheduler,ModelCheckpoint,TerminateOnNaN,TensorBoard,EarlyStopping,ReduceLROnPlateau
from keras_tqdm import TQDMNotebookCallback
from tensorflow.keras.optimizers import Adam, SGD,RMSprop

# %%
contin_inp = Input((contin_cols,), name='contin')
contin_out = Dense(contin_cols*10, activation='relu', name='contin_d')(contin_inp)
embs = [get_emb(feat) for feat in cat_map_fit.features]
x = Concatenate(axis=-1)([emb for inp,emb in embs] + [contin_out])
x = BatchNormalization()(x)
x = Dropout(0.1)(x)
x = Dense(512, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(0.15)(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.2)(x)
x = Dense(1, activation=None)(x)

model = Model([inp for inp,emb in embs] + [contin_inp], x)
model.compile(RMSprop(lr=0.001,clipvalue=0.2), loss=rmspe_loss)

# %% [markdown]
# ### Training Model

# %%
checkpoint_path="saved_model_small"

checkpoint= ModelCheckpoint(f'{weights_save_path}{checkpoint_path}',monitor="val_loss",save_best_only=True,verbose=0)

#lr_schedule= LearningRateScheduler(partial(schedule_lr,base_rate=0.005,interval=8,multiplier=0.7),verbose=1)

term= TerminateOnNaN()
tqdm_callback= TQDMNotebookCallback(leave_inner=True,metric_format='{name}: {value:0.5f}')
early_stop= EarlyStopping(monitor="val_loss",patience=8,min_delta=0,mode="min",verbose=0)
reduce_lr=ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=4, verbose=0, mode='auto', min_delta=0.0005, cooldown=0, min_lr=1e-6)

try:
    model.load_weights(f"{file_save_path}saved_model_backup_0.08792a")
    print("Loading model Weights from previous model")
except:
    print("Not loading model Weights from previous model")
hist = model.fit(map_train, y_train, batch_size=512, epochs=100,
                 verbose=0, validation_data=(map_valid, y_valid),callbacks=[checkpoint,reduce_lr,term,tqdm_callback,early_stop])

plot_history(hist)

print("Reloading Best Checkpointed weights")
model.load_weights(f"{weights_save_path}{checkpoint_path}")
print("Model Training Loss (Without Dropout)=",model.evaluate(map_train,y_train,verbose=0))
print("Model Validation Loss=",model.evaluate(map_valid,y_valid,verbose=0))
# Out:
# Not loading model Weights from previous model
# HBox(children=(IntProgress(value=0, description='Training', style=ProgressStyle(description_width='initial')),…
# HBox(children=(IntProgress(value=0, description='Epoch 0', max=759904, style=ProgressStyle(description_width='…
# HBox(children=(IntProgress(value=0, description='Epoch 1', max=759904, style=ProgressStyle(description_width='…
# HBox(children=(IntProgress(value=0, description='Epoch 2', max=759904, style=ProgressStyle(description_width='…
# HBox(children=(IntProgress(value=0, description='Epoch 3', max=759904, style=ProgressStyle(description_width='…
# HBox(children=(IntProgress(value=0, description='Epoch 4', max=759904, style=ProgressStyle(description_width='…
# HBox(children=(IntProgress(value=0, description='Epoch 5', max=759904, style=ProgressStyle(description_width='…
# HBox(children=(IntProgress(value=0, description='Epoch 6', max=759904, style=ProgressStyle(description_width='…
# HBox(children=(IntProgress(value=0, description='Epoch 7', max=759904, style=ProgressStyle(description_width='…
# HBox(children=(IntProgress(value=0, description='Epoch 8', max=759904, style=ProgressStyle(description_width='…
# HBox(children=(IntProgress(value=0, description='Epoch 9', max=759904, style=ProgressStyle(description_width='…
# HBox(children=(IntProgress(value=0, description='Epoch 10', max=759904, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Epoch 11', max=759904, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Epoch 12', max=759904, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Epoch 13', max=759904, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Epoch 14', max=759904, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Epoch 15', max=759904, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Epoch 16', max=759904, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Epoch 17', max=759904, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Epoch 18', max=759904, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Epoch 19', max=759904, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Epoch 20', max=759904, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Epoch 21', max=759904, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Epoch 22', max=759904, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Epoch 23', max=759904, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Epoch 24', max=759904, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Epoch 25', max=759904, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Epoch 26', max=759904, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Epoch 27', max=759904, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Epoch 28', max=759904, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Epoch 29', max=759904, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Epoch 30', max=759904, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Epoch 31', max=759904, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Epoch 32', max=759904, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Epoch 33', max=759904, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Epoch 34', max=759904, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Epoch 35', max=759904, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Epoch 36', max=759904, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Epoch 37', max=759904, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Epoch 38', max=759904, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Epoch 39', max=759904, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Epoch 40', max=759904, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Epoch 41', max=759904, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Epoch 42', max=759904, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Epoch 43', max=759904, style=ProgressStyle(description_width=…
# Reloading Best Checkpointed weights
# Model Training Loss= 0.061637767314601535
# Model Validation Loss= 0.09207266025764226

# %% [markdown]
# ### Generating Predictions

# %%
preds_submit= generate_preds_df(model,model_weights_path=f'{weights_save_path}saved_backup_small_0.09207')
preds_submit.head()
# Out:
#    Id        Sales
# 0   1  4181.259277
# 1   2  7112.950684
# 2   3  9305.863281
# 3   4  6517.759766
# 4   5  7276.727051

# %%
preds_submit.to_csv(f"{submissions_path}submit_small.csv",index=False)

# %% [markdown]
# ### Plotting Predictions on Train and Validation data

# %%
save_train,save_valid= get_train_and_valid_results(model,model_weights_path=f'{weights_save_path}saved_backup_small_0.09207')

# %%
plot_results("Store",1001)
